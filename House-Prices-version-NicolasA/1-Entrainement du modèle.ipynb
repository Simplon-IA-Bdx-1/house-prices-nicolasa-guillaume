# %%
from pandas import read_csv
from alys import regression as alysCL
from alys import  save as SV
from graph import rViz 
import pandas
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import csv
from biglearn import createNewPred as CP
from biglearn import analyserML as ML

# %% [markdown]
# # Chargement du dataset et entrainement

# %%
CP.loaddDataSet()
# Out:
# Appliquer nouveau split (true or false) ?True
# train full dataset/id : dataset/5dd3c900e47684746801e86d
# valeur split train : 0.8
# valeur split test : 0.2
# Model selectioné : ensemble
# Nom du champs objectif : target
# Nom du fichier exporté : Ml_pred2.csv
# dataset load ok
# predict-lancée
# prediction ok

# %% [markdown]
# # Analyse de la prédiction

# %%
df = read_csv('Pred_Files/ML_pred2.csv')

# %%
alysCL.regr(df)
# Out:
# nom colonne prediction : pred
# nom colonne output : target
# MAPE =  7.73
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0       1          60       RL         65.0     8450   Pave   NaN      Reg
# 1       5          60       RL         84.0    14260   Pave   NaN      IR1
# 2       8          60       RL          NaN    10382   Pave   NaN      IR1
# 3      19          20       RL         66.0    13695   Pave   NaN      Reg
# 4      21          60       RL        101.0    14215   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 286  1425          20       RL          NaN     9503   Pave   NaN      Reg
# 287  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 288  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 289  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 290  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
#     LandContour Utilities  ... MiscVal MoSold YrSold SaleType SaleCondition  \
# 0           Lvl    AllPub  ...       0      2   2008       WD        Normal
# 1           Lvl    AllPub  ...       0     12   2008       WD        Normal
# 2           Lvl    AllPub  ...     350     11   2009       WD        Normal
# 3           Lvl    AllPub  ...       0      6   2008       WD        Normal
# 4           Lvl    AllPub  ...       0     11   2006      New       Partial
# ..          ...       ...  ...     ...    ...    ...      ...           ...
# 286         Lvl    AllPub  ...       0      6   2007       WD        Normal
# 287         Lvl    AllPub  ...       0      4   2009       WD        Normal
# 288         Lvl    AllPub  ...       0      5   2009       WD        Normal
# 289         Lvl    AllPub  ...       0      4   2010       WD        Normal
# 290         Lvl    AllPub  ...       0      2   2010       WD        Normal
#
#      target          pred  pourcerror  errorabs  mape
# 0    208500  208678.69683    0.000857      0.00  7.73
# 1    250000  260470.86313    0.041883      0.04   NaN
# 2    200000  216127.70491    0.080639      0.08   NaN
# 3    159000  153646.92011   -0.033667      0.03   NaN
# 4    325300  324719.78972   -0.001784      0.00   NaN
# ..      ...           ...         ...       ...   ...
# 286  144000  141944.36386   -0.014275      0.01   NaN
# 287  310000  331025.67262    0.067825      0.07   NaN
# 288  121000  109486.96622   -0.095149      0.10   NaN
# 289  157900  155610.01876   -0.014503      0.01   NaN
# 290  210000  205457.91667   -0.021629      0.02   NaN
#
# [291 rows x 85 columns]

# %%
alysCL.posneg(df)
# Out:
# On a 141 erreurs positive, 150 erreurs negative, 0 prediction parfaite
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0       1          60       RL         65.0     8450   Pave   NaN      Reg
# 1       5          60       RL         84.0    14260   Pave   NaN      IR1
# 2       8          60       RL          NaN    10382   Pave   NaN      IR1
# 3      19          20       RL         66.0    13695   Pave   NaN      Reg
# 4      21          60       RL        101.0    14215   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 286  1425          20       RL          NaN     9503   Pave   NaN      Reg
# 287  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 288  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 289  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 290  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
#     LandContour Utilities  ... SaleType SaleCondition  target          pred  \
# 0           Lvl    AllPub  ...       WD        Normal  208500  208678.69683
# 1           Lvl    AllPub  ...       WD        Normal  250000  260470.86313
# 2           Lvl    AllPub  ...       WD        Normal  200000  216127.70491
# 3           Lvl    AllPub  ...       WD        Normal  159000  153646.92011
# 4           Lvl    AllPub  ...      New       Partial  325300  324719.78972
# ..          ...       ...  ...      ...           ...     ...           ...
# 286         Lvl    AllPub  ...       WD        Normal  144000  141944.36386
# 287         Lvl    AllPub  ...       WD        Normal  310000  331025.67262
# 288         Lvl    AllPub  ...       WD        Normal  121000  109486.96622
# 289         Lvl    AllPub  ...       WD        Normal  157900  155610.01876
# 290         Lvl    AllPub  ...       WD        Normal  210000  205457.91667
#
#     pourcerror errorabs  mape  positive erreur  negatif erreur  \
# 0     0.000857     0.00  7.73            141.0           150.0
# 1     0.041883     0.04   NaN              NaN             NaN
# 2     0.080639     0.08   NaN              NaN             NaN
# 3    -0.033667     0.03   NaN              NaN             NaN
# 4    -0.001784     0.00   NaN              NaN             NaN
# ..         ...      ...   ...              ...             ...
# 286  -0.014275     0.01   NaN              NaN             NaN
# 287   0.067825     0.07   NaN              NaN             NaN
# 288  -0.095149     0.10   NaN              NaN             NaN
# 289  -0.014503     0.01   NaN              NaN             NaN
# 290  -0.021629     0.02   NaN              NaN             NaN
#
#      prediction parfaite
# 0                    0.0
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 286                  NaN
# 287                  NaN
# 288                  NaN
# 289                  NaN
# 290                  NaN
#
# [291 rows x 88 columns]

# %%
#Classement des erreurs abs par erreur les plus elevées
df.sort_values("errorabs", axis = 0, ascending = False)
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 101   524          60       RL        130.0    40094   Pave   NaN      IR1
# 271  1325          20       RL         75.0     9986   Pave   NaN      Reg
# 181   875          50       RM         52.0     5720   Pave   NaN      Reg
# 104   534          20       RL         50.0     5000   Pave   NaN      Reg
# 132   667          60       RL          NaN    18450   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 177   853          75       RL         53.0     7128   Pave   NaN      Reg
# 182   876          60       FV         75.0     9000   Pave   NaN      Reg
# 185   884          75       RL         60.0     6204   Pave   NaN      Reg
# 202   990          60       FV         65.0     8125   Pave   NaN      Reg
# 0       1          60       RL         65.0     8450   Pave   NaN      Reg
#
#     LandContour Utilities  ... SaleType SaleCondition  target          pred  \
# 101         Bnk    AllPub  ...      New       Partial  184750  476923.12500
# 271         Lvl    AllPub  ...      New       Partial  147000  286503.46121
# 181         Lvl    AllPub  ...       WD       Abnorml   66500  110924.08625
# 104         Low    AllPub  ...       WD        Normal   39300   64332.91865
# 132         Lvl    AllPub  ...       WD       Abnorml  129000  208828.36905
# ..          ...       ...  ...      ...           ...     ...           ...
# 177         Lvl    AllPub  ...       WD        Normal  164000  163364.01212
# 182         Lvl    AllPub  ...      New       Partial  303477  302158.51296
# 185         Bnk    AllPub  ...       WD        Normal  118500  118663.33333
# 202         Lvl    AllPub  ...      New       Partial  197000  196561.77856
# 0           Lvl    AllPub  ...       WD        Normal  208500  208678.69683
#
#     pourcerror errorabs  mape  positive erreur  negatif erreur  \
# 101   1.581451     1.58   NaN              NaN             NaN
# 271   0.949003     0.95   NaN              NaN             NaN
# 181   0.668031     0.67   NaN              NaN             NaN
# 104   0.636970     0.64   NaN              NaN             NaN
# 132   0.618825     0.62   NaN              NaN             NaN
# ..         ...      ...   ...              ...             ...
# 177  -0.003878     0.00   NaN              NaN             NaN
# 182  -0.004345     0.00   NaN              NaN             NaN
# 185   0.001378     0.00   NaN              NaN             NaN
# 202  -0.002224     0.00   NaN              NaN             NaN
# 0     0.000857     0.00  7.73            141.0           150.0
#
#      prediction parfaite
# 101                  NaN
# 271                  NaN
# 181                  NaN
# 104                  NaN
# 132                  NaN
# ..                   ...
# 177                  NaN
# 182                  NaN
# 185                  NaN
# 202                  NaN
# 0                    0.0
#
# [291 rows x 88 columns]

# %%
SV.extraction(df)
# Out:
# nom du fichier.ex : annalyseErreur.csv
# Extraction commencé
# Extraction terminé

# %%
alysCL.seuil_vs_error(df)
# Out:
# valeur du seuil :0.2
# il y'a 271 erreurs inférieurs à 0.2, il y'a 20 erreurs supérieurs à 0.2
# erreur sous seuil = 93.1271%
# 93.1271

# %%
count = 0
for i in df["Id"] :
    count +=1

s = pandas.Series(range(1,(count +1)))
tablex=s    
    
tabley=df["errorabs"]

for i in tablex :
    df["seuil_applique"] = 0.2
    
tabley2 =df["seuil_applique"]
rViz.graph_double(tablex,tabley,tabley2)
# Out:
# label axe X : id
# label axe y : erreur
# label plot 1 : erreur
# label plot 2 : seuil
# Graph title : Erreur VS seuil

# %% [markdown]
# # Comparaison avec le modéle Deepnet

# %%
CP.loaddDataSet()
# Out:
# Appliquer nouveau split (true or false) ?
# train dataset/id : dataset/5dd3d3f45299631c8201d3eb
# test dataset/id : dataset/5dd3d3f5e47684746801e885
# Model selectioné : deepnet
# Nom du champs objectif : target
# Nom du fichier exporté : Ml_pred3.csv
# dataset load ok
# predict-lancée
# prediction ok

# %%
df2 = read_csv('Pred_Files/ML_pred3.csv')

# %%
alysCL.regr(df2)
# Out:
# nom colonne prediction : pred
# nom colonne output : target
# MAPE =  7.32
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0       1          60       RL         65.0     8450   Pave   NaN      Reg
# 1       5          60       RL         84.0    14260   Pave   NaN      IR1
# 2       8          60       RL          NaN    10382   Pave   NaN      IR1
# 3      19          20       RL         66.0    13695   Pave   NaN      Reg
# 4      21          60       RL        101.0    14215   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 286  1425          20       RL          NaN     9503   Pave   NaN      Reg
# 287  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 288  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 289  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 290  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
#     LandContour Utilities  ... MiscVal MoSold YrSold SaleType SaleCondition  \
# 0           Lvl    AllPub  ...       0      2   2008       WD        Normal
# 1           Lvl    AllPub  ...       0     12   2008       WD        Normal
# 2           Lvl    AllPub  ...     350     11   2009       WD        Normal
# 3           Lvl    AllPub  ...       0      6   2008       WD        Normal
# 4           Lvl    AllPub  ...       0     11   2006      New       Partial
# ..          ...       ...  ...     ...    ...    ...      ...           ...
# 286         Lvl    AllPub  ...       0      6   2007       WD        Normal
# 287         Lvl    AllPub  ...       0      4   2009       WD        Normal
# 288         Lvl    AllPub  ...       0      5   2009       WD        Normal
# 289         Lvl    AllPub  ...       0      4   2010       WD        Normal
# 290         Lvl    AllPub  ...       0      2   2010       WD        Normal
#
#      target          pred  pourcerror  errorabs  mape
# 0    208500  212198.37778    0.017738      0.02  7.32
# 1    250000  338486.85621    0.353947      0.35   NaN
# 2    200000  220859.32395    0.104297      0.10   NaN
# 3    159000  150499.18044   -0.053464      0.05   NaN
# 4    325300  344681.84671    0.059581      0.06   NaN
# ..      ...           ...         ...       ...   ...
# 286  144000  144594.96693    0.004132      0.00   NaN
# 287  310000  314975.12762    0.016049      0.02   NaN
# 288  121000   92163.17952   -0.238321      0.24   NaN
# 289  157900  150831.73522   -0.044764      0.04   NaN
# 290  210000  181647.29965   -0.135013      0.14   NaN
#
# [291 rows x 85 columns]

# %%
alysCL.seuil_vs_error(df2)
# Out:
# valeur du seuil :0.2
# il y'a 271 erreurs inférieurs à 0.2, il y'a 20 erreurs supérieurs à 0.2
# erreur sous seuil = 93.1271%
# 93.1271

# %%
count = 0
for i in df2["Id"] :
    count +=1

s = pandas.Series(range(1,(count +1)))
tablex=s    
    
tabley=df2["errorabs"]

for i in tablex :
    df2["seuil_applique"] = 0.2
    
tabley2 =df2["seuil_applique"]
rViz.graph_double(tablex,tabley,tabley2)
# Out:
# label axe X : id
# label axe y : erreur
# label plot 1 : erreur
# label plot 2 : seuil
# Graph title : Erreur VS Seuil
